# %% [markdown]
# # Age Estimation and Gender Classification
#
# In this assignment, you will train CNN models to estimate a person's age and predict their gender based on face images. Please read carefully all the instructions before you start to write your code.
#
# **Your Tasks**
#
# You are supposed to train two CNN models.
# - Model A: Train a CNN model from scratch, following a few restrictions. Save this model as `age_gender_A.keras`
# - Model B: Fine-tune a pre-trained model to perform the same task. Save this model as `age_gender_B.keras`
#
# **Dataset**
#
# Your models will be trained and validated on a folder `train_val/` containing 5,000 labeled face images (size: 128 x 128), originated from the UTKFace dataset. During the assessment phase, your code will be tested on unseen test data.
#
# **Performance Metric**
#
# The evaluation of your models on the test set will be based on the following metrics:
# - age estimation: - Mean Absolute Error (MAE)
# - gender prediction: accuracy
#
# **GPU Time Management**
#
# Please use the available GPU time wisely, as there are some limitations on free GPU usage. It is said the users can use up to 12 hours in row in Google Colab. But many people found they reached its limit far less than 12 hours. To minimize the risk of reaching the limit, consider the following suggestions:
# 1. Ensure you have a stable internet connection.
# 2. Carefully validate your hyperparameters before starting the training process.
# 3. Based on past experience, each model should be trained in less than 2 hours. If the training time is significantly longer, you may need to adjust your model architecture.

# %% [markdown]
# ## Setting Up: Mount the google drive
# Mount your google drive to the notebook. Also don't forget to **enable GPU** before your training.

# %%
#
# Add your code here
#

# Mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Visualize a few photos
# It's always beneficial to thoroughly understand your data before beginning the training process. To get a first-hand impression of the dataset, please display a minimum of 20 images from the `train_val/` folder, along with their corresponding age and gender labels. This will help you gain initial insights into the dataset.

# %%
#
# Add your code here
#

# Relevant imports
import random
import os
import matplotlib.pyplot as plt
from matplotlib.image import imread

# Extracting the age and gender from the images
age = []
gender = []
race = []
datetime = []

# Folder containing the images
folder = '/content/drive/MyDrive/Colab Notebooks/data/train_val'

# Loop through the files and extract the information from the file names
for images in os.listdir(folder):
  labels = images.split('_')
  age.append(labels[0])
  gender.append(labels[1])
  race.append(labels[2])
  datetime.append(labels[3].split('.')[0])

# Selecting a random subset of images to display
rand = [random.randint(0,5000) for i in range(20)]

# Viewing 20 random images
plt.figure(figsize=(10,10))
for i in range(20):
  plt.subplot(4,5,i+1)
  files = folder + '/' + str(age[rand[i]]) + '_' + str(gender[rand[i]]) + '_' + str(race[rand[i]]) + '_' + str(datetime[rand[i]]) + '.jpg.chip.jpg'
  img = imread(files)
  plt.imshow(img)
  plt.axis
  plt.xlabel(f'Age: {age[rand[i]]}, Gender: {gender[rand[i]]}')

# %% [markdown]
# ## Step 1: Data Pre-Processing
# In this step, you will perform necessary pre-processing tasks before feeding the data into a CNN. The pre-processing includes:
#
# 1. Splitting the data into training and validation sets.
# 2. Loading image data, gender labels and age values, and rescaling pixel values (originally integers between 0 and 255) to the range [0, 1].
# 3. Data augmentation
#
# The first two pre-processing steps have already been completed for you. Your task in this step is limited to:
#
# 3. Data augmentation
#
# Please note:
#
# - Do not modify any part of the provided code except the section marked with ########.
# - Do not rescale the age values to the range [0,1], as the original values are used during the testing stage. Rescaling them would significantly impact testing performance.

# %%
import os
import random
import numpy as np

# Added new imports
import cv2
from tensorflow.keras import layers, Sequential

folder_train_val = '/content/drive/MyDrive/Colab Notebooks/data/train_val'
all_image_files = [file for file in os.listdir(folder_train_val) if file.lower().endswith(('.jpg'))]

# Shuffle the dataset to ensure random distribution
random.seed(0)  # Ensure reproducibility
random.shuffle(all_image_files)

# Calculate the number of images for each set
n_train_val = len(all_image_files)
train_end = int(n_train_val * 0.8)

# Split the dataset
train_image_files = all_image_files[:train_end]
val_image_files = all_image_files[train_end:]
print(f"Number of images for training: {len(train_image_files)}")
print(f"Number of images for validation: {len(val_image_files)}")

def load_imgs_lables(dataset_path,filenames):
  print('load all image data, age and gender labels...')
  images = []
  age_labels = []
  gender_labels = []
  for current_file_name in filenames:
    img = cv2.imread(os.path.join(dataset_path, current_file_name))
    img = img / 255.0  # Normalize pixel values
    labels = current_file_name.split('_')
    age_label = int(labels[0])
    gender_label = int(labels[1])
    age_labels.append(age_label)
    gender_labels.append(gender_label)
    images.append(img)

  # Convert to NumPy arrays
  images = np.array(images)
  age_labels = np.array(age_labels)
  gender_labels = np.array(gender_labels)
  return images, age_labels, gender_labels

# Load data from the training set
train_images, train_age, train_gender = load_imgs_lables(folder_train_val,train_image_files)

# Load data from the validation set
val_images, val_age, val_gender = load_imgs_lables(folder_train_val,val_image_files)

#
######### Add your code for data augmentation here #########
#

# Data Augmentation Layer
data_augmentation = Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomRotation(0.1),
])
# Out:
# Number of images for training: 4000
# Number of images for validation: 1000
# load all image data, age and gender labels...
# load all image data, age and gender labels...

# %%
# Visualize some of the augmented images

# Select a random subset of images to display
num_images_to_show = 5
sample_indices = random.sample(range(len(train_images)), num_images_to_show)
sample_images = train_images[sample_indices]

plt.figure(figsize=(12, 6))

for i, img in enumerate(sample_images):
    augmented_img = data_augmentation(np.expand_dims(img, 0))
    augmented_img_np = augmented_img[0].numpy()

    # Convert from BGR to RGB for displaying with matplotlib (Issue with Matplotlib turning images blue)
    rgb_img = cv2.cvtColor((augmented_img_np * 255).astype(np.uint8), cv2.COLOR_BGR2RGB)

    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(rgb_img)
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## STEP2A: Build your own CNN network
# In this step, you will define your own CNN model for identifying gender and predicting age. Although there are two tasks, you only need to build one CNN model with two outputs. You may refer to online resources for solutions.
#
# Here are the key requirements and restrictions for your network:
# 1.	The input size must be 128 x 128 x 3, which means you **should not resize** the original images. This is because my test code relies on this particular input size. Any other size will cause problem in the testing stage.
# 2.  Please treat the gender classification as a binary problem, i.e., **the output layer for the gender branch has only 1 unit**, instead of 2. Although it is technically correct to treat gender classification as a multi-class problem with 2 classes, i.e., 2 units in the last layer, the test code only supports a 1-unit last-layer configuration for the gender branch.
# 3.	The size of feature maps being fed to the first fully connected layer must be less than 10 x 10, while there is no number limitation about the depth.
# 4.	Incorporate techniques to prevent overfitting as appropriate.
#
# At the end of your implementation, use `modelA.summary()` to display the model architecture and use `plot_model()` to visualize the architecture.

# %%
#
# Add your code here
#

# Necessary imports
import keras.utils
from keras.models import Model
from keras.regularizers import l2

# Initialize learning rate and input shape
l2_val = 0.01
input_shape = (128, 128, 3)

# Define model architecture
base = Sequential([

    # Convolutional layer 1
    layers.Conv2D(16, (3, 3), use_bias=False, kernel_regularizer=l2(l2_val), input_shape=input_shape, strides=1, padding = 'same'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2, 2)),

    # Convolutional layer 2
    layers.Conv2D(32, (3, 3), use_bias=False, kernel_regularizer=l2(l2_val), input_shape=input_shape, strides=1, padding = 'same'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2, 2)),

    # Convolutional layer 3
    layers.Conv2D(64, (2, 2), use_bias=False, kernel_regularizer=l2(l2_val), strides = 1, padding='valid'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2, 2)),
])

# Define the input and apply data augmentation
input = layers.Input(shape=input_shape)
input = data_augmentation(input)
shared_layers = base(input)

# Gender classification branch

# Convolutional layer for Gender
gender = layers.Conv2D(64, (2, 2), use_bias=False, kernel_regularizer=l2(l2_val), strides = 1, padding='valid')(shared_layers)
gender = layers.BatchNormalization()(gender)
gender = layers.Activation('relu')(gender)
gender = layers.MaxPooling2D((2, 2))(gender)


# Flatten the output from the shared layers
gender = layers.Flatten()(gender)

# Dense layer for Gender
gender = layers.Dense(64, use_bias=False, kernel_regularizer=l2(l2_val*10))(gender)
gender = layers.BatchNormalization()(gender)
gender = layers.Activation('relu')(gender)

# Adding Dropout
gender = layers.Dropout(0.85)(gender)

# Output layer for Gender
gender_output = layers.Dense(1, activation='sigmoid', name='gender')(gender)

# Age regression branch

# Addtional convolutional layer 1 for Age
age = layers.Conv2D(128, (3, 3), use_bias=False, kernel_regularizer=l2(l2_val), strides = 1)(shared_layers)
age = layers.BatchNormalization()(age)
age = layers.Activation('relu')(age)
age = layers.MaxPooling2D((2, 2))(age)

# Addtional convolutional layer 2 for Age
age = layers.Conv2D(256, (3, 3), use_bias=False, kernel_regularizer=l2(l2_val), strides=1)(age)
age = layers.BatchNormalization()(age)
age = layers.Activation('relu')(age)
age = layers.MaxPooling2D((2, 2))(age)

# Flatten the output from the extra convolutional layers
age = layers.Flatten()(age)

# Dense layer 1 for Age
age = layers.Dense(512, use_bias=False, kernel_regularizer=l2(l2_val))(age)
age = layers.BatchNormalization()(age)
age = layers.Activation('relu')(age)

# Adding Dropout
age = layers.Dropout(0.3)(age)

# Dense layer 2 for Age
age = layers.Dense(128, use_bias=False, kernel_regularizer=l2(l2_val))(age)
age = layers.BatchNormalization()(age)
age = layers.Activation('relu')(age)

# Adding Dropout
age = layers.Dropout(0.3)(age)

# Output layer for Age
age_output = layers.Dense(1, activation='relu', name='age')(age)

# Create the model
modelA = Model(inputs=input, outputs=[age_output,gender_output])

# compile the model
modelA.summary()
from tensorflow.keras.utils import plot_model
plot_model(modelA, show_shapes=True,dpi=100)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "functional_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ keras_tensor_225CLONE     │ (None, 128, 128, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sequential_4 (Sequential) │ (None, 15, 15, 64)     │         13,680 │ keras_tensor_225CLONE… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_22 (Conv2D)        │ (None, 13, 13, 128)    │         73,728 │ sequential_4[1][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_36    │ (None, 13, 13, 128)    │            512 │ conv2d_22[1][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_36             │ (None, 13, 13, 128)    │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_22          │ (None, 6, 6, 128)      │              0 │ activation_36[1][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_23 (Conv2D)        │ (None, 4, 4, 256)      │        294,912 │ max_pooling2d_22[1][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_37    │ (None, 4, 4, 256)      │          1,024 │ conv2d_23[1][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_37             │ (None, 4, 4, 256)      │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_23          │ (None, 2, 2, 256)      │              0 │ activation_37[1][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_11 (Flatten)      │ (None, 1024)           │              0 │ max_pooling2d_23[1][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_21 (Conv2D)        │ (None, 14, 14, 64)     │         16,384 │ sequential_4[1][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_18 (Dense)          │ (None, 512)            │        524,288 │ flatten_11[1][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_34    │ (None, 14, 14, 64)     │            256 │ conv2d_21[1][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_38    │ (None, 512)            │          2,048 │ dense_18[1][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_34             │ (None, 14, 14, 64)     │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_38             │ (None, 512)            │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_21          │ (None, 7, 7, 64)       │              0 │ activation_34[1][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_18 (Dropout)      │ (None, 512)            │              0 │ activation_38[1][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_10 (Flatten)      │ (None, 3136)           │              0 │ max_pooling2d_21[1][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_19 (Dense)          │ (None, 128)            │         65,536 │ dropout_18[1][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_17 (Dense)          │ (None, 64)             │        200,704 │ flatten_10[1][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_39    │ (None, 128)            │            512 │ dense_19[1][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_35    │ (None, 64)             │            256 │ dense_17[1][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_39             │ (None, 128)            │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_35             │ (None, 64)             │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_19 (Dropout)      │ (None, 128)            │              0 │ activation_39[1][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_17 (Dropout)      │ (None, 64)             │              0 │ activation_35[1][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ age (Dense)               │ (None, 1)              │            129 │ dropout_19[1][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gender (Dense)            │ (None, 1)              │             65 │ dropout_17[1][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,194,034 (4.55 MB)
#  Trainable params: 1,191,506 (4.55 MB)
#  Non-trainable params: 2,528 (9.88 KB)

# %% [markdown]
# ## STEP3A: Compile and train your model
# Compile and train your model here.
# Save your model by `modelA.save(your_model_folder+"age_gender_A.keras")` after training.
#
# **DON'T use any other name for your model file.** This is because my test code relies on this particular model name. Any other file name will cause problem in the testing stage.
#
# **Save the model with `save()`** to save the entire model (including a model's architecture, weights, and training configuration) as a `.keras` zip archive. Don't save it with `save_weights()`.

# %%
#
# Add your code here
#

# Necessary imports
from keras.callbacks import EarlyStopping, LearningRateScheduler

# Define the learning rate scheduler
def scheduler(epoch, lr):
  if epoch < 10:
    return lr
  else:
    return lr * np.exp(-0.1*epoch)

learning_rate_scheduler = LearningRateScheduler(scheduler)

# Define the early stopping criteria
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Compile the model
modelA.compile(loss={'age': 'mae','gender': 'binary_crossentropy'}, metrics={'age': 'mae','gender': 'accuracy'})

# Train the model
history1 = modelA.fit(
    x=train_images,
    y=[train_age, train_gender],
    validation_data=(val_images, [val_age, val_gender]),
    batch_size=32,
    epochs=30,
    callbacks=[learning_rate_scheduler, early_stop],
    )
# Out:
# Epoch 1/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - age_loss: 29.0982 - age_mae: 29.0982 - gender_accuracy: 0.6208 - gender_loss: 0.9085 - loss: 44.8662 - val_age_loss: 32.9277 - val_age_mae: 33.0040 - val_gender_accuracy: 0.5430 - val_gender_loss: 0.6794 - val_loss: 37.7791 - learning_rate: 0.0010
# Epoch 2/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 12s 21ms/step - age_loss: 22.0402 - age_mae: 22.0402 - gender_accuracy: 0.7376 - gender_loss: 0.5680 - loss: 26.1813 - val_age_loss: 32.2890 - val_age_mae: 32.3550 - val_gender_accuracy: 0.7490 - val_gender_loss: 0.6217 - val_loss: 35.7221 - learning_rate: 0.0010
# Epoch 3/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - age_loss: 15.4197 - age_mae: 15.4197 - gender_accuracy: 0.7681 - gender_loss: 0.4929 - loss: 18.6108 - val_age_loss: 10.4646 - val_age_mae: 10.4162 - val_gender_accuracy: 0.8050 - val_gender_loss: 0.5824 - val_loss: 13.6411 - learning_rate: 0.0010
# Epoch 4/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - age_loss: 11.7524 - age_mae: 11.7524 - gender_accuracy: 0.7785 - gender_loss: 0.4780 - loss: 14.8933 - val_age_loss: 11.2563 - val_age_mae: 11.2131 - val_gender_accuracy: 0.8220 - val_gender_loss: 0.4364 - val_loss: 14.3414 - learning_rate: 0.0010
# Epoch 5/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - age_loss: 9.9756 - age_mae: 9.9756 - gender_accuracy: 0.7953 - gender_loss: 0.4461 - loss: 13.1367 - val_age_loss: 14.2155 - val_age_mae: 14.2557 - val_gender_accuracy: 0.8350 - val_gender_loss: 0.3745 - val_loss: 17.3987 - learning_rate: 0.0010
# Epoch 6/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - age_loss: 9.4854 - age_mae: 9.4854 - gender_accuracy: 0.8024 - gender_loss: 0.4274 - loss: 12.6925 - val_age_loss: 12.6528 - val_age_mae: 12.6713 - val_gender_accuracy: 0.8330 - val_gender_loss: 0.3581 - val_loss: 15.8558 - learning_rate: 0.0010
# Epoch 7/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - age_loss: 8.6636 - age_mae: 8.6636 - gender_accuracy: 0.8152 - gender_loss: 0.4395 - loss: 11.9500 - val_age_loss: 10.0007 - val_age_mae: 9.9639 - val_gender_accuracy: 0.8020 - val_gender_loss: 0.4086 - val_loss: 13.2883 - learning_rate: 0.0010
# Epoch 8/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - age_loss: 8.0447 - age_mae: 8.0447 - gender_accuracy: 0.8100 - gender_loss: 0.4107 - loss: 11.3563 - val_age_loss: 10.3861 - val_age_mae: 10.4202 - val_gender_accuracy: 0.8320 - val_gender_loss: 0.3905 - val_loss: 13.7209 - learning_rate: 0.0010
# Epoch 9/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - age_loss: 8.1841 - age_mae: 8.1841 - gender_accuracy: 0.8122 - gender_loss: 0.4214 - loss: 11.5405 - val_age_loss: 8.5633 - val_age_mae: 8.5986 - val_gender_accuracy: 0.8310 - val_gender_loss: 0.3659 - val_loss: 11.9038 - learning_rate: 0.0010
# Epoch 10/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - age_loss: 7.7062 - age_mae: 7.7062 - gender_accuracy: 0.8185 - gender_loss: 0.4117 - loss: 11.0712 - val_age_loss: 10.6699 - val_age_mae: 10.6751 - val_gender_accuracy: 0.8450 - val_gender_loss: 0.3636 - val_loss: 13.9869 - learning_rate: 0.0010
# Epoch 11/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - age_loss: 7.0078 - age_mae: 7.0078 - gender_accuracy: 0.8487 - gender_loss: 0.3422 - loss: 10.1567 - val_age_loss: 7.0388 - val_age_mae: 7.0199 - val_gender_accuracy: 0.8730 - val_gender_loss: 0.3500 - val_loss: 9.9234 - learning_rate: 3.6788e-04
# Epoch 12/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - age_loss: 6.2452 - age_mae: 6.2452 - gender_accuracy: 0.8788 - gender_loss: 0.2968 - loss: 9.0611 - val_age_loss: 6.6480 - val_age_mae: 6.6466 - val_gender_accuracy: 0.8780 - val_gender_loss: 0.2904 - val_loss: 9.3574 - learning_rate: 1.2246e-04
# Epoch 13/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - age_loss: 5.7988 - age_mae: 5.7988 - gender_accuracy: 0.8889 - gender_loss: 0.2749 - loss: 8.4868 - val_age_loss: 6.6024 - val_age_mae: 6.6075 - val_gender_accuracy: 0.8840 - val_gender_loss: 0.2840 - val_loss: 9.2709 - learning_rate: 3.6883e-05
# Epoch 14/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - age_loss: 5.6985 - age_mae: 5.6985 - gender_accuracy: 0.8936 - gender_loss: 0.2722 - loss: 8.3517 - val_age_loss: 6.5562 - val_age_mae: 6.5696 - val_gender_accuracy: 0.8820 - val_gender_loss: 0.2795 - val_loss: 9.2172 - learning_rate: 1.0052e-05
# Epoch 15/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - age_loss: 5.4642 - age_mae: 5.4642 - gender_accuracy: 0.8918 - gender_loss: 0.2616 - loss: 8.0981 - val_age_loss: 6.5419 - val_age_mae: 6.5570 - val_gender_accuracy: 0.8820 - val_gender_loss: 0.2772 - val_loss: 9.1996 - learning_rate: 2.4788e-06
# Epoch 16/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - age_loss: 5.5429 - age_mae: 5.5429 - gender_accuracy: 0.8961 - gender_loss: 0.2652 - loss: 8.1782 - val_age_loss: 6.5355 - val_age_mae: 6.5529 - val_gender_accuracy: 0.8830 - val_gender_loss: 0.2771 - val_loss: 9.1947 - learning_rate: 5.5308e-07
# Epoch 17/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - age_loss: 5.7652 - age_mae: 5.7652 - gender_accuracy: 0.8979 - gender_loss: 0.2533 - loss: 8.3881 - val_age_loss: 6.5341 - val_age_mae: 6.5517 - val_gender_accuracy: 0.8820 - val_gender_loss: 0.2771 - val_loss: 9.1933 - learning_rate: 1.1167e-07
# Epoch 18/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - age_loss: 5.4562 - age_mae: 5.4562 - gender_accuracy: 0.8980 - gender_loss: 0.2576 - loss: 8.0833 - val_age_loss: 6.5369 - val_age_mae: 6.5545 - val_gender_accuracy: 0.8830 - val_gender_loss: 0.2778 - val_loss: 9.1966 - learning_rate: 2.0400e-08
# Epoch 19/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - age_loss: 5.6238 - age_mae: 5.6238 - gender_accuracy: 0.8968 - gender_loss: 0.2470 - loss: 8.2403 - val_age_loss: 6.5326 - val_age_mae: 6.5503 - val_gender_accuracy: 0.8830 - val_gender_loss: 0.2772 - val_loss: 9.1919 - learning_rate: 3.3720e-09
# Epoch 20/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - age_loss: 5.6226 - age_mae: 5.6226 - gender_accuracy: 0.9019 - gender_loss: 0.2505 - loss: 8.2426 - val_age_loss: 6.5328 - val_age_mae: 6.5503 - val_gender_accuracy: 0.8830 - val_gender_loss: 0.2776 - val_loss: 9.1922 - learning_rate: 5.0435e-10
# Epoch 21/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - age_loss: 5.7730 - age_mae: 5.7730 - gender_accuracy: 0.8984 - gender_loss: 0.2494 - loss: 8.3918 - val_age_loss: 6.5344 - val_age_mae: 6.5512 - val_gender_accuracy: 0.8820 - val_gender_loss: 0.2777 - val_loss: 9.1932 - learning_rate: 6.8256e-11
# Epoch 22/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - age_loss: 5.8631 - age_mae: 5.8631 - gender_accuracy: 0.9173 - gender_loss: 0.2416 - loss: 8.4742 - val_age_loss: 6.5332 - val_age_mae: 6.5499 - val_gender_accuracy: 0.8800 - val_gender_loss: 0.2786 - val_loss: 9.1927 - learning_rate: 8.3584e-12
# Epoch 23/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - age_loss: 5.5017 - age_mae: 5.5017 - gender_accuracy: 0.8987 - gender_loss: 0.2444 - loss: 8.1155 - val_age_loss: 6.5315 - val_age_mae: 6.5484 - val_gender_accuracy: 0.8820 - val_gender_loss: 0.2776 - val_loss: 9.1902 - learning_rate: 9.2614e-13
# Epoch 24/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - age_loss: 6.0439 - age_mae: 6.0439 - gender_accuracy: 0.9017 - gender_loss: 0.2331 - loss: 8.6465 - val_age_loss: 6.5352 - val_age_mae: 6.5515 - val_gender_accuracy: 0.8830 - val_gender_loss: 0.2775 - val_loss: 9.1933 - learning_rate: 9.2853e-14
# Epoch 25/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - age_loss: 5.5820 - age_mae: 5.5820 - gender_accuracy: 0.9073 - gender_loss: 0.2456 - loss: 8.1971 - val_age_loss: 6.5307 - val_age_mae: 6.5484 - val_gender_accuracy: 0.8830 - val_gender_loss: 0.2773 - val_loss: 9.1901 - learning_rate: 8.4235e-15
# Epoch 26/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - age_loss: 5.4875 - age_mae: 5.4875 - gender_accuracy: 0.8946 - gender_loss: 0.2539 - loss: 8.1109 - val_age_loss: 6.5381 - val_age_mae: 6.5555 - val_gender_accuracy: 0.8830 - val_gender_loss: 0.2777 - val_loss: 9.1975 - learning_rate: 6.9144e-16
# Epoch 27/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - age_loss: 5.6588 - age_mae: 5.6588 - gender_accuracy: 0.8963 - gender_loss: 0.2552 - loss: 8.2835 - val_age_loss: 6.5390 - val_age_mae: 6.5554 - val_gender_accuracy: 0.8810 - val_gender_loss: 0.2783 - val_loss: 9.1979 - learning_rate: 5.1356e-17
# Epoch 28/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - age_loss: 5.8294 - age_mae: 5.8294 - gender_accuracy: 0.8954 - gender_loss: 0.2528 - loss: 8.4517 - val_age_loss: 6.5362 - val_age_mae: 6.5531 - val_gender_accuracy: 0.8830 - val_gender_loss: 0.2777 - val_loss: 9.1951 - learning_rate: 3.4514e-18
# Epoch 29/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - age_loss: 5.4416 - age_mae: 5.4416 - gender_accuracy: 0.9037 - gender_loss: 0.2472 - loss: 8.0583 - val_age_loss: 6.5367 - val_age_mae: 6.5533 - val_gender_accuracy: 0.8810 - val_gender_loss: 0.2780 - val_loss: 9.1956 - learning_rate: 2.0988e-19
# Epoch 30/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - age_loss: 5.6820 - age_mae: 5.6820 - gender_accuracy: 0.8910 - gender_loss: 0.2550 - loss: 8.3065 - val_age_loss: 6.5307 - val_age_mae: 6.5492 - val_gender_accuracy: 0.8830 - val_gender_loss: 0.2774 - val_loss: 9.1910 - learning_rate: 1.1548e-20

# %%
# Evaluate the model
modelA.evaluate(val_images, [val_age, val_gender])
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - age_loss: 6.5787 - age_mae: 6.5797 - gender_accuracy: 0.8954 - gender_loss: 0.2636 - loss: 9.2125
# [9.190144538879395,
#  6.530717849731445,
#  0.2773342728614807,
#  6.5484466552734375,
#  0.8830000162124634]

# %%
# Save the model
folder_models = '/content/drive/MyDrive/'

modelA.save(folder_models+'age_gender_A.keras')

# %% [markdown]
# ## STEP4A: Draw the learning curves
# Draw four learning curve figures for model A as follows.
# 1.	The loss of the gender classification over the training and validation set
# 2.	The accuracy of the gender classification over the training and validation set
# 3.	The loss of the age estimation over the training and validation set
# 4.	The MAE of the age estimation over the training and validation set

# %%
#
# Add your code here
#

# Get the history of the model
history_dict = history1.history

# Create the figure
fig = plt.figure(figsize=(12, 8))

# Gender classification loss
ax1 = fig.add_subplot(2, 2, 1)
ax1.plot(history_dict['gender_loss'], label='Train Gender Loss')
ax1.plot(history_dict['val_gender_loss'], label='Val Gender Loss')
ax1.set_title('Gender Classification Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.set_ylim([0, 1])
ax1.axvline(x=10, color='green', label='Learning Rate Decreases')
ax1.legend()
ax1.grid(True)

# Gender classification accuracy
ax2 = fig.add_subplot(2, 2, 2)
ax2.plot(history_dict['gender_accuracy'], label='Train Gender Accuracy')
ax2.plot(history_dict['val_gender_accuracy'], label='Val Gender Accuracy')
ax2.set_title('Gender Classification Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.set_ylim([0, 1])
ax2.axvline(x=10, color='green', label='Learning Rate Decreases')
ax2.legend()
ax2.grid(True)

# Age estimation loss
ax3 = fig.add_subplot(2, 2, 3)
ax3.plot(history_dict['age_loss'], label='Train Age Loss')
ax3.plot(history_dict['val_age_loss'], label='Val Age Loss')
ax3.set_title('Age Estimation Loss')
ax3.set_xlabel('Epochs')
ax3.set_ylabel('Loss')
ax3.axvline(x=10, color='green', label='Learning Rate Decreases')
ax3.legend()
ax3.grid(True)

# Age estimation MAE
ax4 = fig.add_subplot(2, 2, 4)
ax4.plot(history_dict['age_mae'], label='Train Age MAE')
ax4.plot(history_dict['val_age_mae'], label='Val Age MAE')
ax4.set_title('Age Estimation MAE')
ax4.set_xlabel('Epochs')
ax4.set_ylabel('Mean Absolute Error')
ax4.axvline(x=10, color='green', label='Learning Rate Decreases')
ax4.legend()
ax4.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## STEP2B: Build a CNN network based on a pre-trained model
# Choose an existing CNN architecture pre-trained on ImageNet and fine-tune it on this dataset.
#
# As with Model A, **do not resize the input image size**.
# Ensure that the output layer for **the gender branch has only 1 unit**.
#
# At the end of the cell, use `modelB.summary()` to display the model architecture and use `plot_model()` to visualize the architecture.

# %% [markdown]
# ## STEP3B: Compile and train your model
# Compile and train your model here.
# Save your model to `age_gender_B.keras` after training.
#
# **DON'T use any other name for your model file.** This is because my test code relies on this particular model name. Any other file name will cause problem in the testing stage.
#
# **Also, save the model with `save()` instead of `save_weights()`.**

# %%
#
# Add your code here
#

# Necessary imports
from keras.applications import VGG16

# Load base VGG16 model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

# Freeze certain layers
base_model.trainable = False

for layer in base_model.layers[-3:]:
    layer.trainable = True

# Create input layer
input = layers.Input(shape=(128, 128, 3))

# Apply augmentation layer
shared_layer = data_augmentation(input)

# Feed input into VGG16
shared_layer = base_model(shared_layer, training = False)

# Flatten the outputs
gender = layers.Flatten()(shared_layer)
age = layers.Flatten()(shared_layer)

# Gender classification branch

# Dense layer 1 for Gender
gender = layers.Dense(128, use_bias=False, kernel_regularizer=l2(l2_val), activation = 'relu')(gender)

# Adding Dropout
gender = layers.Dropout(0.3)(gender)

# Dense layer 2 for Gender
gender = layers.Dense(256, use_bias=False, kernel_regularizer=l2(l2_val), activation = 'relu')(gender)

# Adding Dropout
gender = layers.Dropout(0.5)(gender)

# Output layer for Gender
gender_output = layers.Dense(1, activation='sigmoid', name='gender')(gender)

# Age regression branch

# Dense layer 1 for Age
age = layers.Dense(256, use_bias=False, kernel_regularizer=l2(l2_val))(age)
age = layers.BatchNormalization()(age)
age = layers.Activation('relu')(age)

# Adding Dropout
age = layers.Dropout(0.2)(age)

# Dense layer 2 for Age
age = layers.Dense(512, use_bias=False, kernel_regularizer=l2(l2_val))(age)
age = layers.BatchNormalization()(age)
age = layers.Activation('relu')(age)

# Adding Dropout
age = layers.Dropout(0.2)(age)

# Output layer for Age
age_output = layers.Dense(1, activation='relu', name='age')(age)

# Define model
modelB = Model(inputs=input, outputs=[age_output,gender_output])

# Compile the model
modelB.summary()
from tensorflow.keras.utils import plot_model
plot_model(modelB, show_shapes=True,dpi=100)
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6             │ (None, 128, 128, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sequential (Sequential)   │ (None, 128, 128, 3)    │              0 │ input_layer_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ vgg16 (Functional)        │ (None, 4, 4, 512)      │     14,714,688 │ sequential[2][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_5 (Flatten)       │ (None, 8192)           │              0 │ vgg16[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_9 (Dense)           │ (None, 256)            │      2,097,152 │ flatten_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 256)            │          1,024 │ dense_9[0][0]          │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_11             │ (None, 256)            │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_9 (Dropout)       │ (None, 256)            │              0 │ activation_11[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_4 (Flatten)       │ (None, 8192)           │              0 │ vgg16[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_10 (Dense)          │ (None, 512)            │        131,072 │ dropout_9[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_7 (Dense)           │ (None, 128)            │      1,048,576 │ flatten_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 512)            │          2,048 │ dense_10[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_7 (Dropout)       │ (None, 128)            │              0 │ dense_7[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_12             │ (None, 512)            │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_8 (Dense)           │ (None, 256)            │         32,768 │ dropout_7[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_10 (Dropout)      │ (None, 512)            │              0 │ activation_12[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_8 (Dropout)       │ (None, 256)            │              0 │ dense_8[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ age (Dense)               │ (None, 1)              │            513 │ dropout_10[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gender (Dense)            │ (None, 1)              │            257 │ dropout_8[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 18,028,098 (68.77 MB)
#  Trainable params: 8,031,490 (30.64 MB)
#  Non-trainable params: 9,996,608 (38.13 MB)

# %% [markdown]
# ## STEP4B: Draw the learning curves
# Draw four learning curve figures for model B as follows.
# 1. The loss of the gender classification over the training and validation set
# 2. The accuracy of the gender classification over the training and validation set
# 3. The loss of the age estimation over the training and validation set
# 4. The MAE of the age estimation over the training and validation set

# %%
#
# Add your code here
#

# Define the optimizer
opt = keras.optimizers.Adam(learning_rate=1e-4)

# Compile the model
modelB.compile(optimizer = opt, loss={'age': 'mae','gender': 'binary_crossentropy'}, metrics={'age': 'mae','gender': 'accuracy'})

# Train the model
history2 = modelB.fit(
    x=train_images,
    y=[train_age, train_gender],
    validation_data=(val_images, [val_age, val_gender]),
    batch_size=32,
    epochs=30,
    callbacks=[early_stop]
    )
# Out:
# Epoch 1/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 15s 83ms/step - age_loss: 30.5434 - age_mae: 30.5434 - gender_accuracy: 0.5944 - gender_loss: 0.6927 - loss: 42.6860 - val_age_loss: 27.3084 - val_age_mae: 27.3458 - val_gender_accuracy: 0.7810 - val_gender_loss: 0.4987 - val_loss: 36.6312
# Epoch 2/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 81ms/step - age_loss: 25.2174 - age_mae: 25.2174 - gender_accuracy: 0.7105 - gender_loss: 0.5721 - loss: 33.9728 - val_age_loss: 24.2381 - val_age_mae: 24.2491 - val_gender_accuracy: 0.8240 - val_gender_loss: 0.4105 - val_loss: 31.2964
# Epoch 3/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - age_loss: 22.7921 - age_mae: 22.7921 - gender_accuracy: 0.7977 - gender_loss: 0.4530 - loss: 29.5087 - val_age_loss: 20.3398 - val_age_mae: 20.3378 - val_gender_accuracy: 0.8210 - val_gender_loss: 0.4079 - val_loss: 25.9678
# Epoch 4/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - age_loss: 20.7366 - age_mae: 20.7366 - gender_accuracy: 0.8081 - gender_loss: 0.4190 - loss: 26.1240 - val_age_loss: 21.8609 - val_age_mae: 21.8743 - val_gender_accuracy: 0.8420 - val_gender_loss: 0.3812 - val_loss: 26.4724
# Epoch 5/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - age_loss: 18.7928 - age_mae: 18.7928 - gender_accuracy: 0.8321 - gender_loss: 0.3878 - loss: 23.1944 - val_age_loss: 15.3596 - val_age_mae: 15.4365 - val_gender_accuracy: 0.8570 - val_gender_loss: 0.3389 - val_loss: 19.2053
# Epoch 6/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - age_loss: 17.0841 - age_mae: 17.0841 - gender_accuracy: 0.8318 - gender_loss: 0.3593 - loss: 20.7271 - val_age_loss: 17.9890 - val_age_mae: 18.0007 - val_gender_accuracy: 0.8430 - val_gender_loss: 0.3610 - val_loss: 21.1846
# Epoch 7/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 72ms/step - age_loss: 15.6576 - age_mae: 15.6576 - gender_accuracy: 0.8493 - gender_loss: 0.3461 - loss: 18.7212 - val_age_loss: 15.5176 - val_age_mae: 15.5404 - val_gender_accuracy: 0.8510 - val_gender_loss: 0.3458 - val_loss: 18.2395
# Epoch 8/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - age_loss: 14.7604 - age_mae: 14.7604 - gender_accuracy: 0.8553 - gender_loss: 0.3361 - loss: 17.3765 - val_age_loss: 12.4477 - val_age_mae: 12.5064 - val_gender_accuracy: 0.8720 - val_gender_loss: 0.3219 - val_loss: 14.8294
# Epoch 9/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - age_loss: 13.5875 - age_mae: 13.5875 - gender_accuracy: 0.8523 - gender_loss: 0.3251 - loss: 15.8614 - val_age_loss: 12.1598 - val_age_mae: 12.2075 - val_gender_accuracy: 0.8410 - val_gender_loss: 0.3241 - val_loss: 14.2596
# Epoch 10/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - age_loss: 12.3219 - age_mae: 12.3219 - gender_accuracy: 0.8685 - gender_loss: 0.3224 - loss: 14.3267 - val_age_loss: 12.2678 - val_age_mae: 12.2629 - val_gender_accuracy: 0.8560 - val_gender_loss: 0.3266 - val_loss: 14.0896
# Epoch 11/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - age_loss: 11.6917 - age_mae: 11.6917 - gender_accuracy: 0.8628 - gender_loss: 0.3296 - loss: 13.4929 - val_age_loss: 9.8875 - val_age_mae: 9.9222 - val_gender_accuracy: 0.8540 - val_gender_loss: 0.3579 - val_loss: 11.5925
# Epoch 12/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - age_loss: 11.5567 - age_mae: 11.5567 - gender_accuracy: 0.8684 - gender_loss: 0.3161 - loss: 13.1822 - val_age_loss: 11.9988 - val_age_mae: 12.0554 - val_gender_accuracy: 0.8610 - val_gender_loss: 0.3364 - val_loss: 13.5939
# Epoch 13/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - age_loss: 10.1332 - age_mae: 10.1332 - gender_accuracy: 0.8741 - gender_loss: 0.2954 - loss: 11.6143 - val_age_loss: 11.9701 - val_age_mae: 11.9823 - val_gender_accuracy: 0.8280 - val_gender_loss: 0.3913 - val_loss: 13.4438
# Epoch 14/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - age_loss: 9.8642 - age_mae: 9.8642 - gender_accuracy: 0.8808 - gender_loss: 0.2775 - loss: 11.2205 - val_age_loss: 8.0890 - val_age_mae: 8.1461 - val_gender_accuracy: 0.8710 - val_gender_loss: 0.3101 - val_loss: 9.4605
# Epoch 15/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - age_loss: 8.6061 - age_mae: 8.6061 - gender_accuracy: 0.8811 - gender_loss: 0.2919 - loss: 9.8993 - val_age_loss: 7.5518 - val_age_mae: 7.5504 - val_gender_accuracy: 0.8640 - val_gender_loss: 0.3456 - val_loss: 8.8270
# Epoch 16/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - age_loss: 8.0207 - age_mae: 8.0207 - gender_accuracy: 0.8856 - gender_loss: 0.2759 - loss: 9.2378 - val_age_loss: 8.4290 - val_age_mae: 8.4300 - val_gender_accuracy: 0.8740 - val_gender_loss: 0.3174 - val_loss: 9.6347
# Epoch 17/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - age_loss: 8.0580 - age_mae: 8.0580 - gender_accuracy: 0.8739 - gender_loss: 0.2807 - loss: 9.2310 - val_age_loss: 7.9320 - val_age_mae: 7.9603 - val_gender_accuracy: 0.8700 - val_gender_loss: 0.3159 - val_loss: 9.1274
# Epoch 18/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 72ms/step - age_loss: 7.4089 - age_mae: 7.4089 - gender_accuracy: 0.8850 - gender_loss: 0.2700 - loss: 8.5328 - val_age_loss: 7.4838 - val_age_mae: 7.5189 - val_gender_accuracy: 0.8540 - val_gender_loss: 0.3379 - val_loss: 8.6607
# Epoch 19/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - age_loss: 7.3929 - age_mae: 7.3929 - gender_accuracy: 0.9018 - gender_loss: 0.2496 - loss: 8.4598 - val_age_loss: 7.1971 - val_age_mae: 7.2453 - val_gender_accuracy: 0.8670 - val_gender_loss: 0.3093 - val_loss: 8.3351
# Epoch 20/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - age_loss: 7.2576 - age_mae: 7.2576 - gender_accuracy: 0.8887 - gender_loss: 0.2880 - loss: 8.3316 - val_age_loss: 7.2415 - val_age_mae: 7.2174 - val_gender_accuracy: 0.8660 - val_gender_loss: 0.2992 - val_loss: 8.2724
# Epoch 21/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - age_loss: 6.8099 - age_mae: 6.8099 - gender_accuracy: 0.8863 - gender_loss: 0.2618 - loss: 7.8282 - val_age_loss: 6.6544 - val_age_mae: 6.6875 - val_gender_accuracy: 0.8750 - val_gender_loss: 0.3125 - val_loss: 7.7307
# Epoch 22/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - age_loss: 6.7291 - age_mae: 6.7291 - gender_accuracy: 0.9001 - gender_loss: 0.2482 - loss: 7.7118 - val_age_loss: 6.7622 - val_age_mae: 6.7934 - val_gender_accuracy: 0.8820 - val_gender_loss: 0.3017 - val_loss: 7.7977
# Epoch 23/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - age_loss: 6.5233 - age_mae: 6.5233 - gender_accuracy: 0.9057 - gender_loss: 0.2324 - loss: 7.4673 - val_age_loss: 7.3274 - val_age_mae: 7.3783 - val_gender_accuracy: 0.8350 - val_gender_loss: 0.3889 - val_loss: 8.4356
# Epoch 24/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - age_loss: 6.5419 - age_mae: 6.5419 - gender_accuracy: 0.8778 - gender_loss: 0.2816 - loss: 7.5168 - val_age_loss: 7.0836 - val_age_mae: 7.0653 - val_gender_accuracy: 0.8700 - val_gender_loss: 0.3243 - val_loss: 8.0493
# Epoch 25/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - age_loss: 6.3444 - age_mae: 6.3444 - gender_accuracy: 0.8999 - gender_loss: 0.2387 - loss: 7.2588 - val_age_loss: 6.8275 - val_age_mae: 6.8330 - val_gender_accuracy: 0.8750 - val_gender_loss: 0.3118 - val_loss: 7.7940
# Epoch 26/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - age_loss: 6.0567 - age_mae: 6.0567 - gender_accuracy: 0.9030 - gender_loss: 0.2329 - loss: 6.9471 - val_age_loss: 7.2997 - val_age_mae: 7.3211 - val_gender_accuracy: 0.8670 - val_gender_loss: 0.3336 - val_loss: 8.2822

# %%
# Evaluate the model
modelB.evaluate(val_images, [val_age, val_gender])
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - age_loss: 6.9017 - age_mae: 6.9037 - gender_accuracy: 0.9007 - gender_loss: 0.2719 - loss: 7.9152
# [7.730695724487305,
#  6.654435157775879,
#  0.31249260902404785,
#  6.687524795532227,
#  0.875]

# %%
# Save the model
modelB.save('/content/drive/MyDrive/age_gender_B.keras')

# %%
#
# Add your code here
#

# Get the history of the model
history_dict = history2.history

# Create the figure
fig = plt.figure(figsize=(12, 8))

# Gender classification loss
ax1 = fig.add_subplot(2, 2, 1)
ax1.plot(history_dict['gender_loss'], label='Train Gender Loss')
ax1.plot(history_dict['val_gender_loss'], label='Val Gender Loss')
ax1.set_title('Gender Classification Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.set_ylim([0, 1])
ax1.legend()
ax1.grid(True)

# Gender classification accuracy
ax2 = fig.add_subplot(2, 2, 2)
ax2.plot(history_dict['gender_accuracy'], label='Train Gender Accuracy')
ax2.plot(history_dict['val_gender_accuracy'], label='Val Gender Accuracy')
ax2.set_title('Gender Classification Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.set_ylim([0, 1])
ax2.legend()
ax2.grid(True)

# Age estimation loss
ax3 = fig.add_subplot(2, 2, 3)
ax3.plot(history_dict['age_loss'], label='Train Age Loss')
ax3.plot(history_dict['val_age_loss'], label='Val Age Loss')
ax3.set_title('Age Estimation Loss')
ax3.set_xlabel('Epochs')
ax3.set_ylabel('Loss')
ax3.legend()
ax3.grid(True)

# Age estimation MAE
ax4 = fig.add_subplot(2, 2, 4)
ax4.plot(history_dict['age_mae'], label='Train Age MAE')
ax4.plot(history_dict['val_age_mae'], label='Val Age MAE')
ax4.set_title('Age Estimation MAE')
ax4.set_xlabel('Epochs')
ax4.set_ylabel('Mean Absolute Error')
ax4.legend()
ax4.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## STEP5: Evaluate the model on the test set
# I will load your two models for testing. The test set will not be available before your submission.
#
# The metrics for measuring the performance on the test set are:
# - age estimation: MAE (Mean Absolute Error)
# - gender classification: accuracy

# %%
#
# Don't add code in this cell when submitting this file
#
